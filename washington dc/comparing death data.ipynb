# %% [markdown]
# #### Comparing HepVu death data vs CDC wonder death data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import itertools
from itertools import combinations
from scipy import spatial
import pickle as pickle
import gudhi
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline

# %%
import warnings

# Ignore FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
cdc_df = gpd.read_file('./data/processed data/SVI2020 WashingtonDC counties with death rate/SVI2020_WashingtonDC_counties_with_death_rate.shp')

# %%
hepvu_df = gpd.read_file('./data/processed data//SVI2020 WashingtonDC counties with death rate HepVu/SVI2020_WashingtonDC_counties_with_death_rate_HepVu.shp')

# %%
cdc_df.head(3)
# Out:
#    ST                 STATE ST_ABBR STCNTY                COUNTY   FIPS  \
# 0  11  District of Columbia      DC  11001  District of Columbia  11001
# 1  24              Maryland      MD  24009               Calvert  24009
# 2  24              Maryland      MD  24017               Charles  24017
#
#                                      LOCATION   AREA_SQMI  E_TOTPOP  M_TOTPOP  \
# 0  District of Columbia, District of Columbia   61.126172    701974         0
# 1                    Calvert County, Maryland  213.189517     92094         0
# 2                    Charles County, Maryland  457.823473    161448         0
#
#    ...  MP_NHPI  EP_TWOMORE  MP_TWOMORE  EP_OTHERRA  MP_OTHERRA  Shape_Leng  \
# 0  ...      0.1         2.9         0.2         0.5         0.1    0.645734
# 1  ...      0.1         3.8         0.6         0.1         0.2    1.392130
# 2  ...      0.1         4.7         0.7         0.4         0.2    2.164637
#
#    Shape_Area  Deaths  od_deaths_  \
# 0    0.018374   432.0    0.615407
# 1    0.063610    33.0    0.358330
# 2    0.129562    60.0    0.371637
#
#                                             geometry
# 0  POLYGON ((-77.11976 38.93434, -77.11253 38.940...
# 1  POLYGON ((-76.70121 38.71276, -76.69914 38.715...
# 2  POLYGON ((-77.27382 38.48356, -77.27240 38.489...
#
# [3 rows x 163 columns]

# %%
hepvu_df.head(3)
# Out:
#    ST                 STATE ST_ABBR STCNTY                COUNTY   FIPS  \
# 0  11  District of Columbia      DC  11001  District of Columbia  11001
# 1  24              Maryland      MD  24009               Calvert  24009
# 2  24              Maryland      MD  24017               Charles  24017
#
#                                      LOCATION   AREA_SQMI  E_TOTPOP  M_TOTPOP  \
# 0  District of Columbia, District of Columbia   61.126172    701974         0
# 1                    Calvert County, Maryland  213.189517     92094         0
# 2                    Charles County, Maryland  457.823473    161448         0
#
#    ...  EP_OTHERRA  MP_OTHERRA  Shape_Leng  Shape_Area  GEO ID  State Abbr  \
# 0  ...         0.5         0.1    0.645734    0.018374   11001          DC
# 1  ...         0.1         0.2    1.392130    0.063610   24009          MD
# 2  ...         0.4         0.2    2.164637    0.129562   24017          MD
#
#         County Nam  OP_Rate_20  NOD_Rate_2  \
# 0  District of Col        32.6        58.3
# 1   Calvert County        45.4        34.5
# 2   Charles County        36.9        33.1
#
#                                             geometry
# 0  POLYGON ((-77.11976 38.93434, -77.11253 38.940...
# 1  POLYGON ((-76.70121 38.71276, -76.69914 38.715...
# 2  POLYGON ((-77.27382 38.48356, -77.27240 38.489...
#
# [3 rows x 166 columns]

# %%
# add "Deaths" and "od_deaths_" columns from cdc_df to hepvu_df by matching "FIPS" columns
hepvu_cdc_df = hepvu_df.merge(cdc_df[['FIPS', 'Deaths', 'od_deaths_']], on='FIPS', how='left')

# 7          0  ...    1.030180    0.048052   51043          VA
# 8          0  ...    2.099423    0.102349   51047          VA
# 9          0  ...    2.138721    0.108028   51059          VA
# 10         0  ...    2.289361    0.174885   51061          VA
# 11         0  ...    1.910396    0.140551   51107          VA
# 12         0  ...    1.529031    0.085985   51113          VA
# 13         0  ...    2.272157    0.091839   51153          VA
# 14         0  ...    1.335103    0.071641   51157          VA
# 15         0  ...    1.752948    0.110341   51177          VA
# 16         0  ...    1.383794    0.074504   51179          VA
# 17         0  ...    1.274671    0.058615   51187          VA
# 18         0  ...    0.339699    0.004140   51510          VA
# 19         0  ...    0.228193    0.001685   51600          VA
# 20         0  ...    0.126236    0.000550   51610          VA
# 21         0  ...    0.282246    0.002805   51630          VA
# 22         0  ...    0.333948    0.002655   51683          VA
# 23         0  ...    0.208297    0.000815   51685          VA
# 24         0  ...    1.307481    0.057229   54037          WV
#
#          County Nam  OP_Rate_20  NOD_Rate_2  \
# 0   District of Col        32.6        58.3
# 1    Calvert County        45.4        34.5
# 2    Charles County        36.9        33.1
# 3   Frederick Count        56.6        29.2
# 4   Montgomery Coun        25.0        13.8
# 5   Prince George's        24.8        23.7
# 6   Arlington Count        31.1        13.3
# 7     Clarke County        17.0        18.0
# 8   Culpeper County        21.8        32.7
# 9    Fairfax County        26.3        10.4
# 10  Fauquier County        33.1        21.2
# 11   Loudoun County        17.2         9.4
# 12   Madison County         4.9        22.5
# 13   Prince William        16.3        22.1
# 14  Rappahannock Co         6.8        43.2
# 15  Spotsylvania Co        26.6        33.0
# 16  Stafford County        13.3        22.4
# 17    Warren County        18.1        46.9
# 18  Alexandria city        19.2        13.8
# 19     Fairfax city        58.2        22.5
# 20  Falls Church ci        21.8        11.7
# 21   Fredericksburg       220.4        39.1
# 22    Manassas city        73.4        25.0
# 23  Manassas Park c        -9.0        11.7
# 24  Jefferson Count        23.6        51.9
#
#                                              geometry  Deaths  od_deaths_
# 0   POLYGON ((-77.11976 38.93434, -77.11253 38.940...   432.0    0.615407
# 1   POLYGON ((-76.70121 38.71276, -76.69914 38.715...    33.0    0.358330
# 2   POLYGON ((-77.27382 38.48356, -77.27240 38.489...    60.0    0.371637
# 3   POLYGON ((-77.67716 39.32453, -77.67637 39.330...    80.0    0.312555
# 4   POLYGON ((-77.52728 39.14624, -77.52487 39.148...   149.0    0.142222
# 5   POLYGON ((-77.07995 38.70901, -77.08080 38.710...   227.0    0.249300
# 6   POLYGON ((-77.17228 38.89325, -77.16811 38.896...    38.0    0.160721
# 7   POLYGON ((-78.15170 39.03667, -78.14240 39.061...     0.0    0.000000
# 8   POLYGON ((-78.22915 38.53328, -78.22896 38.534...    19.0    0.365842
# 9   MULTIPOLYGON (((-77.53698 38.84275, -77.53496 ...   121.0    0.105269
# 10  POLYGON ((-78.13127 38.86746, -78.13006 38.870...    11.0    0.156354
# 11  POLYGON ((-77.95640 39.02086, -77.94788 39.022...    38.0    0.093755
# 12  POLYGON ((-78.45280 38.47553, -78.44876 38.482...     5.0    0.378558
# 13  MULTIPOLYGON (((-77.71567 38.84322, -77.70493 ...   111.0    0.237772
# 14  POLYGON ((-78.33518 38.62875, -78.33129 38.627...     5.0    0.679348
# 15  POLYGON ((-77.95364 38.11850, -77.93914 38.132...    53.0    0.393517
# 16  POLYGON ((-77.63422 38.41655, -77.63452 38.418...    38.0    0.253021
# 17  POLYGON ((-78.39124 38.82678, -78.38854 38.828...    23.0    0.576615
# 18  POLYGON ((-77.14380 38.81066, -77.14377 38.810...    24.0    0.151602
# 19  POLYGON ((-77.33480 38.85383, -77.33333 38.856...     5.0    0.214482
# 20  POLYGON ((-77.19471 38.89907, -77.19127 38.899...     0.0    0.000000
# 21  POLYGON ((-77.53086 38.30879, -77.53028 38.309...    16.0    0.550604
# 22  POLYGON ((-77.52666 38.73320, -77.52542 38.735...    12.0    0.292412
# 23  POLYGON ((-77.47879 38.78258, -77.47359 38.788...     5.0    0.284933
# 24  POLYGON ((-78.03545 39.27822, -78.03326 39.279...    33.0    0.579741
#
# [25 rows x 168 columns]

# %%
# If "Deaths" is 5.0 make it "supressed" as well as "od_deaths_"
hepvu_cdc_df['Deaths'] = hepvu_cdc_df['Deaths'].apply(lambda x: 'suppressed' if x == 5.0 else x)

# %%
# Set 'od_deaths_' to 'suppressed' where 'Deaths' is 'suppressed'
hepvu_cdc_df.loc[hepvu_cdc_df['Deaths'] == 'suppressed', 'od_deaths_'] = 'suppressed'

# %%
hepvu_cdc_df[['County Nam','E_TOTPOP','Deaths','od_deaths_','NOD_Rate_2']]
# Out:
#          County Nam  E_TOTPOP      Deaths  od_deaths_  NOD_Rate_2
# 0   District of Col    701974       432.0    0.615407        58.3
# 1    Calvert County     92094        33.0     0.35833        34.5
# 2    Charles County    161448        60.0    0.371637        33.1
# 3   Frederick Count    255955        80.0    0.312555        29.2
# 4   Montgomery Coun   1047661       149.0    0.142222        13.8
# 5   Prince George's    910551       227.0      0.2493        23.7
# 6   Arlington Count    236434        38.0    0.160721        13.3
# 7     Clarke County     14498         0.0         0.0        18.0
# 8   Culpeper County     51935        19.0    0.365842        32.7
# 9    Fairfax County   1149439       121.0    0.105269        10.4
# 10  Fauquier County     70353        11.0    0.156354        21.2
# 11   Loudoun County    405312        38.0    0.093755         9.4
# 12   Madison County     13208  suppressed  suppressed        22.5
# 13   Prince William    466834       111.0    0.237772        22.1
# 14  Rappahannock Co      7360  suppressed  suppressed        43.2
# 15  Spotsylvania Co    134683        53.0    0.393517        33.0
# 16  Stafford County    150185        38.0    0.253021        22.4
# 17    Warren County     39888        23.0    0.576615        46.9
# 18  Alexandria city    158309        24.0    0.151602        13.8
# 19     Fairfax city     23312  suppressed  suppressed        22.5
# 20  Falls Church ci     14309         0.0         0.0        11.7
# 21   Fredericksburg     29059        16.0    0.550604        39.1
# 22    Manassas city     41038        12.0    0.292412        25.0
# 23  Manassas Park c     17548  suppressed  suppressed        11.7
# 24  Jefferson Count     56922        33.0    0.579741        51.9

# %%
# This is how they have calculated the od_deaths_ column
# # create a new column 'od_deaths_per_1000' which is the ratio of 'od_deaths' to 'E_TOTPOP' and multiply by 1000
# metro_svi_deaths['od_deaths_per_1000'] = (metro_svi_deaths['Deaths']/metro_svi_deaths['E_TOTPOP'])*1000
