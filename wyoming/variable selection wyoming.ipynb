# %% [markdown]
# #### SVI data Analysis

# %% [markdown]
# ###### American National Standards Institute (ANSI) Codes for States
# ###### Virginia:VA: 51
# ###### Maryland:MD: 24
# ###### West Virginia:WV: 54
# ###### District of Columbia:DC: 11

# %%
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np
import itertools
from itertools import combinations
from scipy import spatial
import pickle as pickle
import gudhi
from pylab import *
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
import seaborn as sns
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from matplotlib import pyplot
import warnings

# Ignore FutureWarnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# imoporting SVI data for the entire US(county level) 
us_svi = gpd.read_file('./data/SVI data/SVI2020_US_county.gdb')

# %%
# include only the Washington DC, Virginia, Maryland, and West Virginia(county level)
filtered_svi_df = us_svi[us_svi['ST_ABBR'].isin(['VA', 'MD', 'WV', 'DC'])]

# %%
# reset index
filtered_svi_df.reset_index(drop=True, inplace=True)

# %%
# Plot the data for the Washington DC, Virginia, Maryland, and West Virginia(county level)
ax = filtered_svi_df.plot(figsize=(10, 10), column="RPL_THEMES", legend=False, cmap='OrRd', edgecolor='black',linewidth=0.3)

for idx, row in filtered_svi_df.iterrows():
    centroid = row.geometry.centroid
    county_name = row.FIPS
    ax.annotate(text=county_name, xy=(centroid.x, centroid.y), ha='center', fontsize=0.5)

# Display the plot
plt.show()

# %%
# checking the data type of the FIPS column
print(type(filtered_svi_df['FIPS'][0]))
# Out:
# <class 'str'>

# %%
filtered_svi_df.head(3)
# Out:
#    ST                 STATE ST_ABBR STCNTY                COUNTY   FIPS  \
# 0  11  District of Columbia      DC  11001  District of Columbia  11001
# 1  24              Maryland      MD  24001              Allegany  24001
# 2  24              Maryland      MD  24003          Anne Arundel  24003
#
#                                      LOCATION   AREA_SQMI  E_TOTPOP  M_TOTPOP  \
# 0  District of Columbia, District of Columbia   61.126172    701974         0
# 1                   Allegany County, Maryland  422.203330     71002         0
# 2               Anne Arundel County, Maryland  414.809757    575421         0
#
#    ...  MP_AIAN  EP_NHPI  MP_NHPI  EP_TWOMORE  MP_TWOMORE  EP_OTHERRACE  \
# 0  ...      0.1      0.0      0.1         2.9         0.2           0.5
# 1  ...      0.1      0.0      0.1         2.2         0.4           0.1
# 2  ...      0.1      0.0      0.1         4.2         0.4           0.3
#
#    MP_OTHERRACE  Shape_Length  Shape_Area  \
# 0           0.1      0.645734    0.018374
# 1           0.1      2.647485    0.116232
# 2           0.1      2.222859    0.121041
#
#                                             geometry
# 0  MULTIPOLYGON (((-77.11976 38.93434, -77.11253 ...
# 1  MULTIPOLYGON (((-79.06756 39.47944, -79.06003 ...
# 2  MULTIPOLYGON (((-76.83849 39.10421, -76.83047 ...
#
# [3 rows x 161 columns]

# %% [markdown]
# #### Overdose data (2020)
# we need to combine Overdose data to the svi dataframe

# %%
# this contains mortality data for the Washington DC, Virginia, Maryland, and West Virginia(county level)
mortality_df = pd.read_csv('./data/Mortality data/Current Final Multiple Cause of Death Data/DCMetroDeaths_2018_2021.csv')

# %%
# rename county code column to FIPS
mortality_df.rename(columns={'County Code':'FIPS'}, inplace=True)

# %%
# convert FIPS column to string
mortality_df['FIPS'] = mortality_df['FIPS'].astype(str)

# %%
# filtering the mortality data for year 2020
mortality_df_2020 = mortality_df[mortality_df['Year']==2020]
mortality_df_2020.reset_index(drop=True, inplace=True)

# %%
mortality_df_2020.head(3)
# Out:
#   State               County   FIPS  Year  Year Code      Deaths  Population  \
# 0    WV   Barbour County, WV  54001  2020       2020  Suppressed       16444
# 1    WV  Berkeley County, WV  54003  2020       2020         112      122125
# 2    WV     Boone County, WV  54005  2020       2020          24       21055
#
#    Crude Rate
# 0  Suppressed
# 1        91.7
# 2         114

# %%
# Assuming filtered_df has the 'od_deaths' column
od_deaths_counts = mortality_df_2020['Deaths'].value_counts()

# Print the counts of each unique value in the 'od_deaths' column
print(od_deaths_counts)
# Out:
# Suppressed    95
# 10            10
# 12             6
# 0              5
# 17             5
# 18             5
# 11             4
# 22             4
# 19             3
# 16             3
# 38             3
# 21             3
# 13             3
# 33             3
# 24             3
# 30             2
# 112            2
# 29             2
# 37             2
# 23             2
# 60             2
# 49             2
# 35             2
# 26             2
# 99             2
# 15             2
# 52             2
# 34             2
# 14             2
# 194            1
# 106            1
# 80             1
# 442            1
# 59             1
# 36             1
# 149            1
# 227            1
# 122            1
# 104            1
# 46             1
# 20             1
# 849            1
# 280            1
# 53             1
# 75             1
# 146            1
# 54             1
# 87             1
# 69             1
# 65             1
# 111            1
# 28             1
# 121            1
# 126            1
# 103            1
# 39             1
# 40             1
# 67             1
# 432            1
# Name: Deaths, dtype: int64

# %%
# Merge the dataframes on the 'FIPS' column(this will include all the 2020 data for the Washington DC, Virginia, Maryland, and West Virginia(county level))
merged_df_VA_MD_DC_WV = pd.merge(filtered_svi_df, mortality_df_2020[['FIPS', 'Deaths']],
                     on='FIPS', how='left')

# %%
# Rename the 'Provisional Drug Overdose Deaths' column to 'od_deaths'
# merged_df.rename(columns={'Provisional Drug Overdose Deaths': 'od_deaths'}, inplace=True)

# If there are NaN values in 'od_deaths' column, you can fill them with a default value, for example, 0
# merged_df['Deaths'].fillna(0, inplace=True)

# Now, merged_df contains the new column 'od_deaths' based on matching FIPS codes

# %%
merged_df_VA_MD_DC_WV.head(3)
# Out:
#    ST                 STATE ST_ABBR STCNTY                COUNTY   FIPS  \
# 0  11  District of Columbia      DC  11001  District of Columbia  11001
# 1  24              Maryland      MD  24001              Allegany  24001
# 2  24              Maryland      MD  24003          Anne Arundel  24003
#
#                                      LOCATION   AREA_SQMI  E_TOTPOP  M_TOTPOP  \
# 0  District of Columbia, District of Columbia   61.126172    701974         0
# 1                   Allegany County, Maryland  422.203330     71002         0
# 2               Anne Arundel County, Maryland  414.809757    575421         0
#
#    ...  EP_NHPI  MP_NHPI  EP_TWOMORE  MP_TWOMORE  EP_OTHERRACE  MP_OTHERRACE  \
# 0  ...      0.0      0.1         2.9         0.2           0.5           0.1
# 1  ...      0.0      0.1         2.2         0.4           0.1           0.1
# 2  ...      0.0      0.1         4.2         0.4           0.3           0.1
#
#    Shape_Length  Shape_Area  \
# 0      0.645734    0.018374
# 1      2.647485    0.116232
# 2      2.222859    0.121041
#
#                                             geometry  Deaths
# 0  MULTIPOLYGON (((-77.11976 38.93434, -77.11253 ...     432
# 1  MULTIPOLYGON (((-79.06756 39.47944, -79.06003 ...      52
# 2  MULTIPOLYGON (((-76.83849 39.10421, -76.83047 ...     280
#
# [3 rows x 162 columns]

# %% [markdown]
# ##### Now I need to extract specifically Washington DC Metropolitan Area SVI dataset.

# %%
# this contais Washington DC Metro area counties(shapefile)
metro_map_df = gpd.read_file('./data/DC_Metro_counties/Washington_Arlington_Alexandria_DC_VA_MD_WV_Counties.shp')

# %%
metro_map_df.head(3)
# Out:
#    OBJECTID STATEFP COUNTYFP  COUNTYNS  GEOID             NAME  \
# 0       734      54      037  01550025  54037        Jefferson
# 1      1266      24      009  01676636  24009          Calvert
# 2      1297      24      033  01714670  24033  Prince George's
#
#                  NAMELSAD LSAD CLASSFP  MTFCC  ... Shape_Area  CBSAFP  \
# 0        Jefferson County   06      H1  G4020  ...   0.057252   47900
# 1          Calvert County   06      H1  G4020  ...   0.092340   47900
# 2  Prince George's County   06      H1  G4020  ...   0.134028   47900
#
#    METDIVFP CSAFP                                    CBSA_Title  \
# 0     47894   548  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 1     47894   548  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 2     47894   548  Washington-Arlington-Alexandria, DC-VA-MD-WV
#
#                         M_Status  \
# 0  Metropolitan Statistical Area
# 1  Metropolitan Statistical Area
# 2  Metropolitan Statistical Area
#
#                                      MDIV_Title  \
# 0  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 1  Washington-Arlington-Alexandria, DC-VA-MD-WV
# 2  Washington-Arlington-Alexandria, DC-VA-MD-WV
#
#                                         CSA_Title  C_Status  \
# 0  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA  Outlying
# 1  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA  Outlying
# 2  Washington-Baltimore-Arlington, DC-MD-VA-WV-PA   Central
#
#                                             geometry
# 0  POLYGON ((-78.03541 39.27841, -78.03526 39.278...
# 1  POLYGON ((-76.56813 38.40771, -76.57181 38.408...
# 2  POLYGON ((-77.04202 38.74672, -77.04191 38.750...
#
# [3 rows x 26 columns]

# %%
# In the metro shapefile GEOID contains the FIPS code
# metro_svi_deaths will contains SVI and fatalities data for the Washington DC Metro area counties
metro_svi_deaths = merged_df_VA_MD_DC_WV[merged_df_VA_MD_DC_WV['FIPS'].isin(metro_map_df['GEOID'].tolist())]
metro_svi_deaths.reset_index(drop=True, inplace=True)

# %%
# Plot the data side by side using subplots
fig, axes = plt.subplots(1, 2, figsize=(10, 10))

# Plot for filtered_result (assuming filtered_result is your filtered dataframe)
ax1 = metro_svi_deaths.plot(ax=axes[0], column="RPL_THEMES", legend=False, cmap='OrRd', edgecolor='black', linewidth=0.3)
ax1.set_title('Metro SVI heatmap')

# Plot for filtered_merged_df (assuming filtered_merged_df is your first filtered dataframe)
ax2 = metro_svi_deaths.plot(ax=axes[1], column="Deaths", legend=False, cmap='OrRd', edgecolor='black', linewidth=0.3)
ax2.set_title('Metro OD deaths heatmap')

# Annotate the plots
for ax in [ax1, ax2]:
    for idx, row in metro_svi_deaths.iterrows():
        centroid = row.geometry.centroid
        county_name = row.FIPS
        ax.annotate(text=county_name, xy=(centroid.x, centroid.y), ha='center', fontsize=4)

# Display the plots
plt.show()

# %%
metro_svi_deaths
# Out:
#     ST                 STATE ST_ABBR STCNTY                COUNTY   FIPS  \
# 0   11  District of Columbia      DC  11001  District of Columbia  11001
# 1   24              Maryland      MD  24009               Calvert  24009
# 2   24              Maryland      MD  24017               Charles  24017
# 3   24              Maryland      MD  24021             Frederick  24021
# 4   24              Maryland      MD  24031            Montgomery  24031
# 5   24              Maryland      MD  24033       Prince George's  24033
# 6   51              Virginia      VA  51013             Arlington  51013
# 7   51              Virginia      VA  51043                Clarke  51043
# 8   51              Virginia      VA  51047              Culpeper  51047
# 9   51              Virginia      VA  51059               Fairfax  51059
# 10  51              Virginia      VA  51061              Fauquier  51061
# 11  51              Virginia      VA  51107               Loudoun  51107
# 12  51              Virginia      VA  51113               Madison  51113
# 13  51              Virginia      VA  51153        Prince William  51153
# 14  51              Virginia      VA  51157          Rappahannock  51157
# 15  51              Virginia      VA  51177          Spotsylvania  51177
# 16  51              Virginia      VA  51179              Stafford  51179
# 17  51              Virginia      VA  51187                Warren  51187
# 18  51              Virginia      VA  51510       Alexandria City  51510
# 19  51              Virginia      VA  51600          Fairfax City  51600
# 20  51              Virginia      VA  51610     Falls Church City  51610
# 21  51              Virginia      VA  51630   Fredericksburg City  51630
# 22  51              Virginia      VA  51683         Manassas City  51683
# 23  51              Virginia      VA  51685    Manassas Park City  51685
# 24  54         West Virginia      WV  54037             Jefferson  54037
#
#                                       LOCATION   AREA_SQMI  E_TOTPOP  \
# 0   District of Columbia, District of Columbia   61.126172    701974
# 1                     Calvert County, Maryland  213.189517     92094
# 2                     Charles County, Maryland  457.823473    161448
# 3                   Frederick County, Maryland  660.590349    255955
# 4                  Montgomery County, Maryland  493.109662   1047661
# 5             Prince George's County, Maryland  482.649590    910551
# 6                   Arlington County, Virginia   25.997402    236434
# 7                      Clarke County, Virginia  175.932838     14498
# 8                    Culpeper County, Virginia  379.186591     51935
# 9                     Fairfax County, Virginia  391.020748   1149439
# 10                   Fauquier County, Virginia  647.993458     70353
# 11                    Loudoun County, Virginia  515.738016    405312
# 12                    Madison County, Virginia  320.638292     13208
# 13             Prince William County, Virginia  335.256218    466834
# 14               Rappahannock County, Virginia  266.372126      7360
# 15               Spotsylvania County, Virginia  401.411889    134683
# 16                   Stafford County, Virginia  269.204890    150185
# 17                     Warren County, Virginia  214.597038     39888
# 18                   Alexandria city, Virginia   14.935328    158309
# 19                      Fairfax city, Virginia    6.240462     23312
# 20                 Falls Church city, Virginia    2.046442     14309
# 21               Fredericksburg city, Virginia   10.450429     29059
# 22                     Manassas city, Virginia    9.842994     41038
# 23                Manassas Park city, Virginia    3.033815     17548
# 24             Jefferson County, West Virginia  209.295463     56922
#
#     M_TOTPOP  ...  EP_NHPI  MP_NHPI  EP_TWOMORE  MP_TWOMORE  EP_OTHERRACE  \
# 0          0  ...      0.0      0.1         2.9         0.2           0.5
# 1          0  ...      0.0      0.1         3.8         0.6           0.1
# 2          0  ...      0.0      0.1         4.7         0.7           0.4
# 3          0  ...      0.1      0.1         3.3         0.3           0.2
# 4          0  ...      0.0      0.1         3.7         0.2           0.7
# 5          0  ...      0.0      0.1         2.7         0.2           0.5
# 6          0  ...      0.1      0.1         3.8         0.4           0.5
# 7          0  ...      0.0      0.3         1.9         1.0           0.5
# 8          0  ...      0.1      0.2         4.2         1.1           0.5
# 9          0  ...      0.1      0.1         3.9         0.2           0.4
# 10         0  ...      0.0      0.1         2.3         0.5           0.1
# 11         0  ...      0.1      0.1         3.9         0.3           0.6
# 12         0  ...      0.0      0.3         2.2         1.2           0.0
# 13         0  ...      0.1      0.1         3.9         0.3           0.4
# 14         0  ...      0.0      0.5         2.3         0.8           0.2
# 15         0  ...      0.1      0.1         3.7         0.5           0.3
# 16         0  ...      0.1      0.1         5.4         0.7           0.3
# 17         0  ...      0.0      0.1         3.2         0.8           0.2
# 18         0  ...      0.1      0.1         3.5         0.5           0.3
# 19         0  ...      0.0      0.2         3.6         1.0           0.0
# 20         0  ...      0.0      0.3         3.7         1.0           0.1
# 21         0  ...      0.1      0.1         8.0         1.7           0.3
# 22         0  ...      0.0      0.1         4.0         1.3           0.7
# 23         0  ...      0.0      0.2         2.0         1.3           0.1
# 24         0  ...      0.0      0.1         3.1         0.5           0.7
#
#     MP_OTHERRACE  Shape_Length  Shape_Area  \
# 0            0.1      0.645734    0.018374
# 1            0.2      1.392130    0.063610
# 2            0.2      2.164637    0.129562
# 3            0.1      2.120478    0.180981
# 4            0.1      1.841432    0.136786
# 5            0.1      2.146588    0.134026
# 6            0.2      0.403757    0.006995
# 7            0.7      1.030180    0.048052
# 8            0.5      2.099423    0.102349
# 9            0.1      2.138721    0.108028
# 10           0.1      2.289361    0.174885
# 11           0.1      1.910396    0.140551
# 12           0.3      1.529031    0.085985
# 13           0.1      2.272157    0.091839
# 14           0.4      1.335103    0.071641
# 15           0.2      1.752948    0.110341
# 16           0.1      1.383794    0.074504
# 17           0.2      1.274671    0.058615
# 18           0.2      0.339699    0.004140
# 19           0.1      0.228193    0.001685
# 20           0.2      0.126236    0.000550
# 21           0.2      0.282246    0.002805
# 22           0.5      0.333948    0.002655
# 23           0.2      0.208297    0.000815
# 24           0.4      1.307481    0.057229
#
#                                              geometry      Deaths
# 0   MULTIPOLYGON (((-77.11976 38.93434, -77.11253 ...         432
# 1   MULTIPOLYGON (((-76.70121 38.71276, -76.69914 ...          33
# 2   MULTIPOLYGON (((-77.27382 38.48356, -77.27240 ...          60
# 3   MULTIPOLYGON (((-77.67716 39.32453, -77.67637 ...          80
# 4   MULTIPOLYGON (((-77.52728 39.14624, -77.52487 ...         149
# 5   MULTIPOLYGON (((-77.07995 38.70901, -77.08080 ...         227
# 6   MULTIPOLYGON (((-77.17228 38.89325, -77.16811 ...          38
# 7   MULTIPOLYGON (((-78.15170 39.03667, -78.14240 ...           0
# 8   MULTIPOLYGON (((-78.22915 38.53328, -78.22896 ...          19
# 9   MULTIPOLYGON (((-77.53698 38.84275, -77.53496 ...         121
# 10  MULTIPOLYGON (((-78.13127 38.86746, -78.13006 ...          11
# 11  MULTIPOLYGON (((-77.95640 39.02086, -77.94788 ...          38
# 12  MULTIPOLYGON (((-78.45280 38.47553, -78.44876 ...  Suppressed
# 13  MULTIPOLYGON (((-77.71567 38.84322, -77.70493 ...         111
# 14  MULTIPOLYGON (((-78.33518 38.62875, -78.33129 ...  Suppressed
# 15  MULTIPOLYGON (((-77.95364 38.11850, -77.93914 ...          53
# 16  MULTIPOLYGON (((-77.63422 38.41655, -77.63452 ...          38
# 17  MULTIPOLYGON (((-78.39124 38.82678, -78.38854 ...          23
# 18  MULTIPOLYGON (((-77.14380 38.81066, -77.14377 ...          24
# 19  MULTIPOLYGON (((-77.33480 38.85383, -77.33333 ...  Suppressed
# 20  MULTIPOLYGON (((-77.19471 38.89907, -77.19127 ...           0
# 21  MULTIPOLYGON (((-77.53086 38.30879, -77.53028 ...          16
# 22  MULTIPOLYGON (((-77.52666 38.73320, -77.52542 ...          12
# 23  MULTIPOLYGON (((-77.47879 38.78258, -77.47359 ...  Suppressed
# 24  MULTIPOLYGON (((-78.03545 39.27822, -78.03326 ...          33
#
# [25 rows x 162 columns]

# %%
# make "Suppressed" values in the Deaths column to 5   
metro_svi_deaths['Deaths'].replace('Suppressed', 5, inplace=True)
# Out:
# /var/folders/j3/904q7dbj02j_jyjz7pvfgz384d40kw/T/ipykernel_38102/506533984.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   metro_svi_deaths['Deaths'].replace('Suppressed', 5, inplace=True)

# %%
# check the data type of the Deaths column
print(type(metro_svi_deaths['Deaths'][0]))
# Out:
# <class 'str'>

# %%
# convert Deaths column to float
metro_svi_deaths['Deaths'] = metro_svi_deaths['Deaths'].astype(float)
# Out:
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# create a new column 'od_deaths_per_1000' which is the ratio of 'od_deaths' to 'E_TOTPOP' and multiply by 1000
metro_svi_deaths['od_deaths_per_1000'] = (metro_svi_deaths['Deaths']/metro_svi_deaths['E_TOTPOP'])*1000
# Out:
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/geopandas/geodataframe.py:1543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
metro_svi_deaths
# Out:
#     ST                 STATE ST_ABBR STCNTY                COUNTY   FIPS  \
# 0   11  District of Columbia      DC  11001  District of Columbia  11001
# 1   24              Maryland      MD  24009               Calvert  24009
# 2   24              Maryland      MD  24017               Charles  24017
# 3   24              Maryland      MD  24021             Frederick  24021
# 4   24              Maryland      MD  24031            Montgomery  24031
# 5   24              Maryland      MD  24033       Prince George's  24033
# 6   51              Virginia      VA  51013             Arlington  51013
# 7   51              Virginia      VA  51043                Clarke  51043
# 8   51              Virginia      VA  51047              Culpeper  51047
# 9   51              Virginia      VA  51059               Fairfax  51059
# 10  51              Virginia      VA  51061              Fauquier  51061
# 11  51              Virginia      VA  51107               Loudoun  51107
# 12  51              Virginia      VA  51113               Madison  51113
# 13  51              Virginia      VA  51153        Prince William  51153
# 14  51              Virginia      VA  51157          Rappahannock  51157
# 15  51              Virginia      VA  51177          Spotsylvania  51177
# 16  51              Virginia      VA  51179              Stafford  51179
# 17  51              Virginia      VA  51187                Warren  51187
# 18  51              Virginia      VA  51510       Alexandria City  51510
# 19  51              Virginia      VA  51600          Fairfax City  51600
# 20  51              Virginia      VA  51610     Falls Church City  51610
# 21  51              Virginia      VA  51630   Fredericksburg City  51630
# 22  51              Virginia      VA  51683         Manassas City  51683
# 23  51              Virginia      VA  51685    Manassas Park City  51685
# 24  54         West Virginia      WV  54037             Jefferson  54037
#
#                                       LOCATION   AREA_SQMI  E_TOTPOP  \
# 0   District of Columbia, District of Columbia   61.126172    701974
# 1                     Calvert County, Maryland  213.189517     92094
# 2                     Charles County, Maryland  457.823473    161448
# 3                   Frederick County, Maryland  660.590349    255955
# 4                  Montgomery County, Maryland  493.109662   1047661
# 5             Prince George's County, Maryland  482.649590    910551
# 6                   Arlington County, Virginia   25.997402    236434
# 7                      Clarke County, Virginia  175.932838     14498
# 8                    Culpeper County, Virginia  379.186591     51935
# 9                     Fairfax County, Virginia  391.020748   1149439
# 10                   Fauquier County, Virginia  647.993458     70353
# 11                    Loudoun County, Virginia  515.738016    405312
# 12                    Madison County, Virginia  320.638292     13208
# 13             Prince William County, Virginia  335.256218    466834
# 14               Rappahannock County, Virginia  266.372126      7360
# 15               Spotsylvania County, Virginia  401.411889    134683
# 16                   Stafford County, Virginia  269.204890    150185
# 17                     Warren County, Virginia  214.597038     39888
# 18                   Alexandria city, Virginia   14.935328    158309
# 19                      Fairfax city, Virginia    6.240462     23312
# 20                 Falls Church city, Virginia    2.046442     14309
# 21               Fredericksburg city, Virginia   10.450429     29059
# 22                     Manassas city, Virginia    9.842994     41038
# 23                Manassas Park city, Virginia    3.033815     17548
# 24             Jefferson County, West Virginia  209.295463     56922
#
#     M_TOTPOP  ...  MP_NHPI  EP_TWOMORE  MP_TWOMORE  EP_OTHERRACE  \
# 0          0  ...      0.1         2.9         0.2           0.5
# 1          0  ...      0.1         3.8         0.6           0.1
# 2          0  ...      0.1         4.7         0.7           0.4
# 3          0  ...      0.1         3.3         0.3           0.2
# 4          0  ...      0.1         3.7         0.2           0.7
# 5          0  ...      0.1         2.7         0.2           0.5
# 6          0  ...      0.1         3.8         0.4           0.5
# 7          0  ...      0.3         1.9         1.0           0.5
# 8          0  ...      0.2         4.2         1.1           0.5
# 9          0  ...      0.1         3.9         0.2           0.4
# 10         0  ...      0.1         2.3         0.5           0.1
# 11         0  ...      0.1         3.9         0.3           0.6
# 12         0  ...      0.3         2.2         1.2           0.0
# 13         0  ...      0.1         3.9         0.3           0.4
# 14         0  ...      0.5         2.3         0.8           0.2
# 15         0  ...      0.1         3.7         0.5           0.3
# 16         0  ...      0.1         5.4         0.7           0.3
# 17         0  ...      0.1         3.2         0.8           0.2
# 18         0  ...      0.1         3.5         0.5           0.3
# 19         0  ...      0.2         3.6         1.0           0.0
# 20         0  ...      0.3         3.7         1.0           0.1
# 21         0  ...      0.1         8.0         1.7           0.3
# 22         0  ...      0.1         4.0         1.3           0.7
# 23         0  ...      0.2         2.0         1.3           0.1
# 24         0  ...      0.1         3.1         0.5           0.7
#
#     MP_OTHERRACE  Shape_Length  Shape_Area  \
# 0            0.1      0.645734    0.018374
# 1            0.2      1.392130    0.063610
# 2            0.2      2.164637    0.129562
# 3            0.1      2.120478    0.180981
# 4            0.1      1.841432    0.136786
# 5            0.1      2.146588    0.134026
# 6            0.2      0.403757    0.006995
# 7            0.7      1.030180    0.048052
# 8            0.5      2.099423    0.102349
# 9            0.1      2.138721    0.108028
# 10           0.1      2.289361    0.174885
# 11           0.1      1.910396    0.140551
# 12           0.3      1.529031    0.085985
# 13           0.1      2.272157    0.091839
# 14           0.4      1.335103    0.071641
# 15           0.2      1.752948    0.110341
# 16           0.1      1.383794    0.074504
# 17           0.2      1.274671    0.058615
# 18           0.2      0.339699    0.004140
# 19           0.1      0.228193    0.001685
# 20           0.2      0.126236    0.000550
# 21           0.2      0.282246    0.002805
# 22           0.5      0.333948    0.002655
# 23           0.2      0.208297    0.000815
# 24           0.4      1.307481    0.057229
#
#                                              geometry  Deaths  \
# 0   MULTIPOLYGON (((-77.11976 38.93434, -77.11253 ...   432.0
# 1   MULTIPOLYGON (((-76.70121 38.71276, -76.69914 ...    33.0
# 2   MULTIPOLYGON (((-77.27382 38.48356, -77.27240 ...    60.0
# 3   MULTIPOLYGON (((-77.67716 39.32453, -77.67637 ...    80.0
# 4   MULTIPOLYGON (((-77.52728 39.14624, -77.52487 ...   149.0
# 5   MULTIPOLYGON (((-77.07995 38.70901, -77.08080 ...   227.0
# 6   MULTIPOLYGON (((-77.17228 38.89325, -77.16811 ...    38.0
# 7   MULTIPOLYGON (((-78.15170 39.03667, -78.14240 ...     0.0
# 8   MULTIPOLYGON (((-78.22915 38.53328, -78.22896 ...    19.0
# 9   MULTIPOLYGON (((-77.53698 38.84275, -77.53496 ...   121.0
# 10  MULTIPOLYGON (((-78.13127 38.86746, -78.13006 ...    11.0
# 11  MULTIPOLYGON (((-77.95640 39.02086, -77.94788 ...    38.0
# 12  MULTIPOLYGON (((-78.45280 38.47553, -78.44876 ...     5.0
# 13  MULTIPOLYGON (((-77.71567 38.84322, -77.70493 ...   111.0
# 14  MULTIPOLYGON (((-78.33518 38.62875, -78.33129 ...     5.0
# 15  MULTIPOLYGON (((-77.95364 38.11850, -77.93914 ...    53.0
# 16  MULTIPOLYGON (((-77.63422 38.41655, -77.63452 ...    38.0
# 17  MULTIPOLYGON (((-78.39124 38.82678, -78.38854 ...    23.0
# 18  MULTIPOLYGON (((-77.14380 38.81066, -77.14377 ...    24.0
# 19  MULTIPOLYGON (((-77.33480 38.85383, -77.33333 ...     5.0
# 20  MULTIPOLYGON (((-77.19471 38.89907, -77.19127 ...     0.0
# 21  MULTIPOLYGON (((-77.53086 38.30879, -77.53028 ...    16.0
# 22  MULTIPOLYGON (((-77.52666 38.73320, -77.52542 ...    12.0
# 23  MULTIPOLYGON (((-77.47879 38.78258, -77.47359 ...     5.0
# 24  MULTIPOLYGON (((-78.03545 39.27822, -78.03326 ...    33.0
#
#     od_deaths_per_1000
# 0             0.615407
# 1             0.358330
# 2             0.371637
# 3             0.312555
# 4             0.142222
# 5             0.249300
# 6             0.160721
# 7             0.000000
# 8             0.365842
# 9             0.105269
# 10            0.156354
# 11            0.093755
# 12            0.378558
# 13            0.237772
# 14            0.679348
# 15            0.393517
# 16            0.253021
# 17            0.576615
# 18            0.151602
# 19            0.214482
# 20            0.000000
# 21            0.550604
# 22            0.292412
# 23            0.284933
# 24            0.579741
#
# [25 rows x 163 columns]

# %% [markdown]
# #### Now we need to select the socioeconmics variables and deaths data to create a prediction model to find most important variables
# 'E_TOTPOP','EP_POV150','EP_UNEMP','EP_HBURD','EP_NOHSDP','EP_UNINSUR','EP_AGE65','EP_AGE17','EP_DISABL','EP_SNGPNT','EP_LIMENG','EP_MINRTY','EP_MUNIT','EP_MOBILE','EP_CROWD','EP_NOVEH','EP_GROUPQ','EP_NOINT','EP_AFAM','EP_HISP','EP_ASIAN','EP_AIAN','EP_NHPI','EP_TWOMORE','EP_OTHERRACE','od_deaths_per_1000'

# %% [markdown]
# ##### Socioeconomic variables
# ###### EP_POV150    Percentage of persons below 150% poverty estimate
# ###### EP_UNEMP    Unemployment Rate estimate
# ###### EP_HBURD    Percentage of housing cost-burdened occupied housing units with annual income less than $75,000 (30%+ of income spent on housing costs) estimate, 2016-2020 ACS estimate, 2016-2020 ACS
# ###### EP_NOHSDP   Percentage of persons with no high school diploma (age 25+) estimate
# ###### EP_UNINSUR  Percentage uninsured in the total civilian noninstitutionalized population estimate, 2016-2020 ACS

# %%
# socioeconomic variable into a list
socioeconomic_variable_names = ['EP_POV150','EP_UNEMP','EP_HBURD','EP_NOHSDP','EP_UNINSUR']

# %%
# filter metro_svi_deaths dataframe to include only the socioeconomic variables and od_deaths_per_1000
metro_svi_deaths_socioeconomic = metro_svi_deaths[socioeconomic_variable_names + ['od_deaths_per_1000']]

# %%
metro_svi_deaths_socioeconomic
# Out:
#     EP_POV150  EP_UNEMP  EP_HBURD  EP_NOHSDP  EP_UNINSUR  od_deaths_per_1000
# 0        21.3       7.1      27.2        8.1         3.7            0.615407
# 1         8.0       3.8      19.0        5.7         3.3            0.358330
# 2        10.9       4.4      21.8        6.4         4.2            0.371637
# 3        10.4       4.1      21.4        7.4         4.5            0.312555
# 4        11.7       4.6      24.0        8.6         6.8            0.142222
# 5        14.2       6.4      29.8       12.8        10.3            0.249300
# 6        10.4       2.8      21.2        5.1         6.0            0.160721
# 7        11.0       3.0      23.4        8.3         8.7            0.000000
# 8        14.2       4.0      23.3       12.9         9.6            0.365842
# 9        10.0       4.1      20.0        7.3         8.1            0.105269
# 10        9.0       2.9      19.5        8.1         7.9            0.156354
# 11        6.3       3.6      14.8        6.1         5.5            0.093755
# 12       18.6       4.1      23.4       11.4         7.4            0.378558
# 13       11.4       5.0      22.0       10.8        10.7            0.237772
# 14       14.2       4.2      21.4        9.1        13.5            0.679348
# 15       12.0       6.0      22.0        8.7         7.6            0.393517
# 16        8.7       3.8      18.5        7.0         7.8            0.253021
# 17       17.0       5.8      21.8       12.1        10.3            0.576615
# 18       14.8       3.3      26.1        7.0         9.6            0.151602
# 19       13.4       4.0      20.3        7.4         6.7            0.214482
# 20        3.7       4.4      18.0        3.2         2.6            0.000000
# 21       19.5       5.8      33.5        7.8         9.9            0.550604
# 22       15.5       4.4      30.3       14.3        16.7            0.292412
# 23       15.7       3.1      37.0       22.1        17.2            0.284933
# 24       14.8       5.7      21.0        9.5         5.1            0.579741

# %%
# create a correlation matrix
corr_matrix = metro_svi_deaths_socioeconomic.corr()

# plot the correlation matrix
plt.figure(figsize=(5, 5))
sns.heatmap(corr_matrix, annot=True, cmap='OrRd')   
plt.show()

# %%
# split the metro_svi_deaths_socioeconomic data into train and test sets
from sklearn.model_selection import train_test_split

# %%
# create X and y
X = metro_svi_deaths_socioeconomic.drop('od_deaths_per_1000', axis=1)
y = metro_svi_deaths_socioeconomic['od_deaths_per_1000']

# %%
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %% [markdown]
# ### Feature Selection Methods

# %% [markdown]
# ### Wrapper feature selection methods

# %% [markdown]
# #### 1. Forward Feature Selection

# %%
selectedVariables = ['EP_POV150','EP_UNEMP','EP_HBURD','EP_NOHSDP','EP_UNINSUR','EP_AGE65','EP_AGE17','EP_DISABL','EP_SNGPNT','EP_LIMENG','EP_MINRTY','EP_MUNIT','EP_MOBILE','EP_CROWD','EP_NOVEH','EP_GROUPQ','od_deaths_per_1000']

# %%
selectedVariablesWithoutY = ['EP_POV150','EP_UNEMP','EP_HBURD','EP_NOHSDP','EP_UNINSUR','EP_AGE65','EP_AGE17','EP_DISABL','EP_SNGPNT','EP_LIMENG','EP_MINRTY','EP_MUNIT','EP_MOBILE','EP_CROWD','EP_NOVEH','EP_GROUPQ']

# %%
# filter metro_svi_deaths dataframe to include only the selected variables and od_deaths_per_1000
metroSviMultipleVariablesDf = metro_svi_deaths[selectedVariables]

# %%
# create X and y
X = metroSviMultipleVariablesDf.drop('od_deaths_per_1000', axis=1)
y = metroSviMultipleVariablesDf['od_deaths_per_1000']

# %%
#forward feature selection
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression

# %%
# calling the linear regression model

lreg = LinearRegression()
sfs1 = SFS(lreg, k_features=4, forward=True, verbose=2, scoring='neg_mean_squared_error')

# %%
sfs1 = sfs1.fit(X, y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.1s finished
#
# [2023-11-08 10:33:14] Features: 1/4 -- score: -0.020635672106346523[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.1s finished
#
# [2023-11-08 10:33:15] Features: 2/4 -- score: -0.017257112739309903[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.0s finished
#
# [2023-11-08 10:33:15] Features: 3/4 -- score: -0.015423742394538031[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.0s finished
#
# [2023-11-08 10:33:15] Features: 4/4 -- score: -0.015847505829490027

# %%
feat_names = list(sfs1.k_feature_names_)
print(feat_names)
# Out:
# ['EP_POV150', 'EP_UNEMP', 'EP_DISABL', 'EP_CROWD']

# %%
# Which features?
feat_cols = list(sfs1.k_feature_idx_)
print(feat_cols)
# Out:
# [0, 1, 7, 13]

# %% [markdown]
# #### 2. Backward Feature Selection

# %%
# calling the linear regression model

lreg = LinearRegression()
sfs2 = SFS(lreg, k_features=4, forward=False, verbose=2, scoring='neg_mean_squared_error')

# %%
sfs2 = sfs2.fit(X, y)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 15/4 -- score: -0.1647253744817704[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 14/4 -- score: -0.11284444488459222[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 13/4 -- score: -0.08259296181406421[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 12/4 -- score: -0.06333788986407289[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 11/4 -- score: -0.04743939321709756[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 10/4 -- score: -0.039367383219763526[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 9/4 -- score: -0.031365739772549105[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 8/4 -- score: -0.027317823601278334[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 7/4 -- score: -0.02433251314111099[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 6/4 -- score: -0.02265431162968113[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 5/4 -- score: -0.019831093601577497[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.0s finished
#
# [2023-11-09 19:54:58] Features: 4/4 -- score: -0.01885483868000959

# %%
feat_names = list(sfs2.k_feature_names_)
print(feat_names)
# Out:
# ['EP_POV150', 'EP_NOHSDP', 'EP_MINRTY', 'EP_MUNIT']

# %% [markdown]
# ### Embedded feature selection method

# %% [markdown]
# #### Lasso regression

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, KFold

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
print("Shape of Train Features: {}".format(X_train.shape))
print("Shape of Test Features: {}".format(X_test.shape))
print("Shape of Train Target: {}".format(y_train.shape))
print("Shape of Test Target: {}".format(y_test.shape))
# Out:
# Shape of Train Features: (20, 16)
# Shape of Test Features: (5, 16)
# Shape of Train Target: (20,)
# Shape of Test Target: (5,)

# %%
# parameters to be tested on GridSearchCV
params = {"alpha":np.arange(0.00001, 10, 500)}

# %%
# Number of Folds and adding the random state for replication
kf=KFold(n_splits=5,shuffle=True, random_state=42)

# %%
# Initializing the Model
lasso = Lasso()

# %%
# GridSearchCV with model, params and folds.
lasso_cv=GridSearchCV(lasso, param_grid=params, cv=kf)
lasso_cv.fit(X, y)
print("Best Params {}".format(lasso_cv.best_params_))
# Out:
# Best Params {'alpha': 1e-05}
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.418e-02, tolerance: 8.008e-05
#   model = cd_fast.enet_coordinate_descent(
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.613e-02, tolerance: 8.072e-05
#   model = cd_fast.enet_coordinate_descent(
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.888e-02, tolerance: 5.174e-05
#   model = cd_fast.enet_coordinate_descent(
# /Users/h6x/anaconda3/envs/TDA/lib/python3.11/site-packages/sklearn/linear_model/_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.724e-03, tolerance: 5.664e-05
#   model = cd_fast.enet_coordinate_descent(

# %%
names=metroSviMultipleVariablesDf.drop("od_deaths_per_1000", axis=1).columns
print("Column Names: {}".format(names.values))
# Out:
# Column Names: ['EP_POV150' 'EP_UNEMP' 'EP_HBURD' 'EP_NOHSDP' 'EP_UNINSUR' 'EP_AGE65'
#  'EP_AGE17' 'EP_DISABL' 'EP_SNGPNT' 'EP_LIMENG' 'EP_MINRTY' 'EP_MUNIT'
#  'EP_MOBILE' 'EP_CROWD' 'EP_NOVEH' 'EP_GROUPQ']

# %%
#Using Lasso Regressor to plot the best features.

# calling the model with the best parameter
lasso1 = Lasso(alpha=0.00001)
lasso1.fit(X_train, y_train)

# Using np.abs() to make coefficients positive.  
lasso1_coef = np.abs(lasso1.coef_)

# %%
# plotting the Column Names and Importance of Columns. 
plt.bar(names, lasso1_coef)
plt.xticks(rotation=90)
plt.grid()
plt.title("Feature Selection Based on Lasso")
plt.xlabel("Features")
plt.ylabel("Importance")
plt.ylim(0, 0.15)
plt.show()

# %%
# Subsetting the features which has more than 0.001 importance.
feature_subset=np.array(names)[lasso1_coef>0.001]
print("Selected Feature Columns: {}".format(feature_subset))
# Out:
# Selected Feature Columns: ['EP_POV150' 'EP_UNEMP' 'EP_HBURD' 'EP_NOHSDP' 'EP_UNINSUR' 'EP_AGE65'
#  'EP_AGE17' 'EP_DISABL' 'EP_SNGPNT' 'EP_LIMENG' 'EP_MINRTY' 'EP_MUNIT'
#  'EP_MOBILE' 'EP_CROWD' 'EP_NOVEH' 'EP_GROUPQ']

# %%
#################

# %%
from sklearn.preprocessing import StandardScaler

# %%
# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# Out:
#     EP_POV150  EP_UNEMP  EP_HBURD  EP_NOHSDP  EP_UNINSUR  EP_AGE65  EP_AGE17  \
# 9        10.0       4.1      20.0        7.3         8.1      13.5      23.5
# 13       11.4       5.0      22.0       10.8        10.7       9.9      27.1
# 1         8.0       3.8      19.0        5.7         3.3      14.9      23.2
# 22       15.5       4.4      30.3       14.3        16.7      10.4      26.7
# 5        14.2       6.4      29.8       12.8        10.3      13.3      22.3
# 2        10.9       4.4      21.8        6.4         4.2      12.5      24.0
# 12       18.6       4.1      23.4       11.4         7.4      23.2      20.8
# 15       12.0       6.0      22.0        8.7         7.6      14.1      24.8
# 3        10.4       4.1      21.4        7.4         4.5      14.5      23.2
# 4        11.7       4.6      24.0        8.6         6.8      15.5      23.2
# 20        3.7       4.4      18.0        3.2         2.6      13.2      24.5
# 17       17.0       5.8      21.8       12.1        10.3      15.9      21.8
# 21       19.5       5.8      33.5        7.8         9.9      10.9      20.8
# 18       14.8       3.3      26.1        7.0         9.6      11.6      18.4
# 24       14.8       5.7      21.0        9.5         5.1      16.2      22.2
# 7        11.0       3.0      23.4        8.3         8.7      21.0      19.5
# 10        9.0       2.9      19.5        8.1         7.9      16.5      23.2
# 14       14.2       4.2      21.4        9.1        13.5      25.9      18.8
# 19       13.4       4.0      20.3        7.4         6.7      15.3      21.7
# 6        10.4       2.8      21.2        5.1         6.0      10.8      18.0
#
#     EP_DISABL  EP_SNGPNT  EP_LIMENG  EP_MINRTY  EP_MUNIT  EP_MOBILE  EP_CROWD  \
# 9         7.2        5.1        6.2       50.0      22.8        0.5       3.0
# 13        7.9        6.4        5.8       58.3      13.5        1.1       3.2
# 1         9.9        4.6        0.3       22.4       3.7        0.9       0.5
# 22        6.8        8.3       11.9       60.4      17.3        1.3       4.7
# 5         9.7        8.2        6.9       87.7      22.5        0.4       4.3
# 2         9.9        8.2        1.0       61.7       5.8        0.9       1.8
# 12       13.5        4.6        0.2       15.3       0.4        3.6       3.2
# 15       11.3        5.3        1.6       32.7       6.6        4.2       2.0
# 3        10.3        5.9        1.8       27.6      10.3        0.9       1.4
# 4         8.5        5.9        6.4       56.9      27.5        0.1       3.1
# 20        7.0        6.9        2.8       28.8      42.7        0.0       3.0
# 17       14.3        6.0        0.5       13.7       3.3        1.2       3.0
# 21       12.3        6.9        3.3       41.9      29.8        0.4       3.0
# 18        7.5        4.3        5.1       48.4      52.4        0.0       4.2
# 24       12.8        3.9        0.5       17.2       1.9        7.1       1.8
# 7        12.7        3.3        1.1       14.7       3.0        0.3       0.7
# 10        9.7        5.8        1.6       20.5       4.3        1.7       0.8
# 14       15.0        2.1        0.4       11.7       0.2        0.7       1.6
# 19        6.5        3.1        4.8       44.6      17.6        0.0       1.9
# 6         6.0        3.3        3.8       39.2      54.1        0.1       3.5
#
#     EP_NOVEH  EP_GROUPQ
# 9        4.4        0.8
# 13       2.3        0.8
# 1        2.8        0.6
# 22       4.2        0.2
# 5        9.2        2.0
# 2        3.2        1.3
# 12       1.6        1.5
# 15       3.0        0.3
# 3        4.0        1.9
# 4        7.5        0.8
# 20       6.3        0.3
# 17       4.9        1.9
# 21       8.2        8.7
# 18      10.4        0.9
# 24       4.9        2.5
# 7        3.5        1.4
# 10       3.1        0.5
# 14       2.7        0.1
# 19       6.0        2.8
# 6       13.9        1.5

# %%
scaler = StandardScaler().fit(X_train[selectedVariablesWithoutY]) 
X_train = scaler.transform(X_train[selectedVariablesWithoutY])

X_test = scaler.transform(X_test[selectedVariablesWithoutY])

# %%
X_train
# Out:
#     EP_POV150  EP_UNEMP  EP_HBURD  EP_NOHSDP  EP_UNINSUR  EP_AGE65  EP_AGE17  \
# 9        10.0       4.1      20.0        7.3         8.1      13.5      23.5
# 13       11.4       5.0      22.0       10.8        10.7       9.9      27.1
# 1         8.0       3.8      19.0        5.7         3.3      14.9      23.2
# 22       15.5       4.4      30.3       14.3        16.7      10.4      26.7
# 5        14.2       6.4      29.8       12.8        10.3      13.3      22.3
# 2        10.9       4.4      21.8        6.4         4.2      12.5      24.0
# 12       18.6       4.1      23.4       11.4         7.4      23.2      20.8
# 15       12.0       6.0      22.0        8.7         7.6      14.1      24.8
# 3        10.4       4.1      21.4        7.4         4.5      14.5      23.2
# 4        11.7       4.6      24.0        8.6         6.8      15.5      23.2
# 20        3.7       4.4      18.0        3.2         2.6      13.2      24.5
# 17       17.0       5.8      21.8       12.1        10.3      15.9      21.8
# 21       19.5       5.8      33.5        7.8         9.9      10.9      20.8
# 18       14.8       3.3      26.1        7.0         9.6      11.6      18.4
# 24       14.8       5.7      21.0        9.5         5.1      16.2      22.2
# 7        11.0       3.0      23.4        8.3         8.7      21.0      19.5
# 10        9.0       2.9      19.5        8.1         7.9      16.5      23.2
# 14       14.2       4.2      21.4        9.1        13.5      25.9      18.8
# 19       13.4       4.0      20.3        7.4         6.7      15.3      21.7
# 6        10.4       2.8      21.2        5.1         6.0      10.8      18.0
#
#     EP_DISABL  EP_SNGPNT  EP_LIMENG  EP_MINRTY  EP_MUNIT  EP_MOBILE  EP_CROWD  \
# 9         7.2        5.1        6.2       50.0      22.8        0.5       3.0
# 13        7.9        6.4        5.8       58.3      13.5        1.1       3.2
# 1         9.9        4.6        0.3       22.4       3.7        0.9       0.5
# 22        6.8        8.3       11.9       60.4      17.3        1.3       4.7
# 5         9.7        8.2        6.9       87.7      22.5        0.4       4.3
# 2         9.9        8.2        1.0       61.7       5.8        0.9       1.8
# 12       13.5        4.6        0.2       15.3       0.4        3.6       3.2
# 15       11.3        5.3        1.6       32.7       6.6        4.2       2.0
# 3        10.3        5.9        1.8       27.6      10.3        0.9       1.4
# 4         8.5        5.9        6.4       56.9      27.5        0.1       3.1
# 20        7.0        6.9        2.8       28.8      42.7        0.0       3.0
# 17       14.3        6.0        0.5       13.7       3.3        1.2       3.0
# 21       12.3        6.9        3.3       41.9      29.8        0.4       3.0
# 18        7.5        4.3        5.1       48.4      52.4        0.0       4.2
# 24       12.8        3.9        0.5       17.2       1.9        7.1       1.8
# 7        12.7        3.3        1.1       14.7       3.0        0.3       0.7
# 10        9.7        5.8        1.6       20.5       4.3        1.7       0.8
# 14       15.0        2.1        0.4       11.7       0.2        0.7       1.6
# 19        6.5        3.1        4.8       44.6      17.6        0.0       1.9
# 6         6.0        3.3        3.8       39.2      54.1        0.1       3.5
#
#     EP_NOVEH  EP_GROUPQ
# 9        4.4        0.8
# 13       2.3        0.8
# 1        2.8        0.6
# 22       4.2        0.2
# 5        9.2        2.0
# 2        3.2        1.3
# 12       1.6        1.5
# 15       3.0        0.3
# 3        4.0        1.9
# 4        7.5        0.8
# 20       6.3        0.3
# 17       4.9        1.9
# 21       8.2        8.7
# 18      10.4        0.9
# 24       4.9        2.5
# 7        3.5        1.4
# 10       3.1        0.5
# 14       2.7        0.1
# 19       6.0        2.8
# 6       13.9        1.5

# %%
reg = Lasso(alpha=1)
reg.fit(X_train, y_train)
# Out:
# Lasso(alpha=1)

# %%
print('R squared training set', round(reg.score(X_train, y_train)*100, 2))
print('R squared test set', round(reg.score(X_test, y_test)*100, 2))
# Out:
# R squared training set 13.3
# R squared test set -31.09

# %%
from sklearn.metrics import mean_squared_error

# Training data
pred_train = reg.predict(X_train)
mse_train = mean_squared_error(y_train, pred_train)
print('MSE training set', round(mse_train, 2))

# Test data
pred = reg.predict(X_test)
mse_test =mean_squared_error(y_test, pred)
print('MSE test set', round(mse_test, 2))
# Out:
# MSE training set 0.03
# MSE test set 0.04

# %%
import numpy as np
import matplotlib.pyplot as plt

alphas = np.linspace(0.01,500,100)
lasso = Lasso(max_iter=10000)
coefs = []

for a in alphas:
    lasso.set_params(alpha=a)
    lasso.fit(X_train, y_train)
    coefs.append(lasso.coef_)

ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('Standardized Coefficients')
plt.title('Lasso coefficients as a function of alpha');

# %% [markdown]
# ### Filter feature selection methods

# %%
metroSviMultipleVariablesDf
# Out:
#     EP_POV150  EP_UNEMP  EP_HBURD  EP_NOHSDP  EP_UNINSUR  EP_AGE65  EP_AGE17  \
# 0        21.3       7.1      27.2        8.1         3.7      12.2      18.0
# 1         8.0       3.8      19.0        5.7         3.3      14.9      23.2
# 2        10.9       4.4      21.8        6.4         4.2      12.5      24.0
# 3        10.4       4.1      21.4        7.4         4.5      14.5      23.2
# 4        11.7       4.6      24.0        8.6         6.8      15.5      23.2
# 5        14.2       6.4      29.8       12.8        10.3      13.3      22.3
# 6        10.4       2.8      21.2        5.1         6.0      10.8      18.0
# 7        11.0       3.0      23.4        8.3         8.7      21.0      19.5
# 8        14.2       4.0      23.3       12.9         9.6      15.8      24.4
# 9        10.0       4.1      20.0        7.3         8.1      13.5      23.5
# 10        9.0       2.9      19.5        8.1         7.9      16.5      23.2
# 11        6.3       3.6      14.8        6.1         5.5       9.4      28.1
# 12       18.6       4.1      23.4       11.4         7.4      23.2      20.8
# 13       11.4       5.0      22.0       10.8        10.7       9.9      27.1
# 14       14.2       4.2      21.4        9.1        13.5      25.9      18.8
# 15       12.0       6.0      22.0        8.7         7.6      14.1      24.8
# 16        8.7       3.8      18.5        7.0         7.8      10.4      26.0
# 17       17.0       5.8      21.8       12.1        10.3      15.9      21.8
# 18       14.8       3.3      26.1        7.0         9.6      11.6      18.4
# 19       13.4       4.0      20.3        7.4         6.7      15.3      21.7
# 20        3.7       4.4      18.0        3.2         2.6      13.2      24.5
# 21       19.5       5.8      33.5        7.8         9.9      10.9      20.8
# 22       15.5       4.4      30.3       14.3        16.7      10.4      26.7
# 23       15.7       3.1      37.0       22.1        17.2       8.7      25.9
# 24       14.8       5.7      21.0        9.5         5.1      16.2      22.2
#
#     EP_DISABL  EP_SNGPNT  EP_LIMENG  EP_MINRTY  EP_MUNIT  EP_MOBILE  EP_CROWD  \
# 0        11.4        6.9        2.4       63.3      46.8        0.1       3.6
# 1         9.9        4.6        0.3       22.4       3.7        0.9       0.5
# 2         9.9        8.2        1.0       61.7       5.8        0.9       1.8
# 3        10.3        5.9        1.8       27.6      10.3        0.9       1.4
# 4         8.5        5.9        6.4       56.9      27.5        0.1       3.1
# 5         9.7        8.2        6.9       87.7      22.5        0.4       4.3
# 6         6.0        3.3        3.8       39.2      54.1        0.1       3.5
# 7        12.7        3.3        1.1       14.7       3.0        0.3       0.7
# 8        13.3        5.0        3.1       31.0       5.8        3.1       2.8
# 9         7.2        5.1        6.2       50.0      22.8        0.5       3.0
# 10        9.7        5.8        1.6       20.5       4.3        1.7       0.8
# 11        6.1        4.8        3.8       44.9      12.4        0.5       1.6
# 12       13.5        4.6        0.2       15.3       0.4        3.6       3.2
# 13        7.9        6.4        5.8       58.3      13.5        1.1       3.2
# 14       15.0        2.1        0.4       11.7       0.2        0.7       1.6
# 15       11.3        5.3        1.6       32.7       6.6        4.2       2.0
# 16        8.6        6.8        2.4       40.2       5.8        2.4       1.7
# 17       14.3        6.0        0.5       13.7       3.3        1.2       3.0
# 18        7.5        4.3        5.1       48.4      52.4        0.0       4.2
# 19        6.5        3.1        4.8       44.6      17.6        0.0       1.9
# 20        7.0        6.9        2.8       28.8      42.7        0.0       3.0
# 21       12.3        6.9        3.3       41.9      29.8        0.4       3.0
# 22        6.8        8.3       11.9       60.4      17.3        1.3       4.7
# 23        8.9        8.3       10.9       67.5      21.7        0.0       6.5
# 24       12.8        3.9        0.5       17.2       1.9        7.1       1.8
#
#     EP_NOVEH  EP_GROUPQ  od_deaths_per_1000
# 0       35.4        5.6            0.615407
# 1        2.8        0.6            0.358330
# 2        3.2        1.3            0.371637
# 3        4.0        1.9            0.312555
# 4        7.5        0.8            0.142222
# 5        9.2        2.0            0.249300
# 6       13.9        1.5            0.160721
# 7        3.5        1.4            0.000000
# 8        3.2        2.8            0.365842
# 9        4.4        0.8            0.105269
# 10       3.1        0.5            0.156354
# 11       2.7        0.5            0.093755
# 12       1.6        1.5            0.378558
# 13       2.3        0.8            0.237772
# 14       2.7        0.1            0.679348
# 15       3.0        0.3            0.393517
# 16       2.1        2.5            0.253021
# 17       4.9        1.9            0.576615
# 18      10.4        0.9            0.151602
# 19       6.0        2.8            0.214482
# 20       6.3        0.3            0.000000
# 21       8.2        8.7            0.550604
# 22       4.2        0.2            0.292412
# 23       3.0        0.0            0.284933
# 24       4.9        2.5            0.579741

# %%
# measure the pearson correlation between the variables
from scipy.stats import pearsonr

# calculate Pearson's correlation matrix   
corr_matrix = metroSviMultipleVariablesDf.corr()

# plot the correlation matrix
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
#Create scatter plots to visually inspect the relationship between each pair of variables
sns.pairplot(metroSviMultipleVariablesDf)
plt.show()

# %% [markdown]
# #### When nonlinear relations are expected we employ Spearman’s Rho

# %%
# calculate Spearman’s Rho	
from scipy.stats import spearmanr

# calculate spearman's correlation
coef, p = spearmanr(metroSviMultipleVariablesDf)
# print('Spearmans correlation coefficient: %.3f' % coef)

#plot the heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(coef, annot=True, xticklabels=metroSviMultipleVariablesDf.columns, yticklabels=metroSviMultipleVariablesDf.columns)
plt.show()
